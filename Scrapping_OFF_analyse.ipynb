# %%
# Import des packages
import pandas as pd
import numpy as np

# Application de paramètres pour le confort visuel
from IPython.core.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_rows', 100)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# off_df = pd.read_csv('off.csv', error_bad_lines=False) # Chargement du csv si nécessaire
off_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Nom                  1993 non-null   object
#  1   Code_Barre           1993 non-null   object
#  2   Nutriscore           1993 non-null   object
#  3   Novascore            1991 non-null   object
#  4   Ecoscore             1993 non-null   object
#  5   Quantite             1993 non-null   object
#  6   Conditionnement      1993 non-null   object
#  7   Marques              1993 non-null   object
#  8   Categories           1993 non-null   object
#  9   Labels               1993 non-null   object
#  10  Origine_Ingredients  1993 non-null   object
#  11  Pays_Transformation  1993 non-null   object
#  12  Code_tracage         1993 non-null   object
#  13  URL                  1993 non-null   object
#  14  Magasins             1993 non-null   object
# ...

# %%
off_df
# Out:
#                                                     Nom     Code_Barre  \
# 0        Riz à la Méditerranéenne - Uncle Ben's - 250 g  3487400003805
# 1     Tartine bio craquant au sarrasin - Le pain des...        1153208
# 2                 Pur sirop d'érable - Maple joe - 250g  3088542500285
# 3             Quinoa poulet sesame - Jardin Bio - 250 g  3478820003193
# 4     Kinder schokobons bonbons de chocolat au lait ...  8000500242612
# ...                                                 ...            ...
# 1988                P'tit Nature Complet - Bjorg - 200g  3229820021027
# 1989  Tartines craquantes au sarrasin - Terres et cé...  3421557604089
# 1990    Céréales Corn Flakes Kellogg's Original - 500 g  3159470000120
# 1991  Country Crisp - Chocolat noir 70% cacao - Jord...  5010477348395
# 1992          Noir Prodigieux 90% cacao - Lindt - 100 g  3046920029759
#
#      Nutriscore                                          Novascore Ecoscore  \
# ...

# %%
# Remplacement des 'XXX' par Nan pour plus de lisibilité
off_df = off_df.replace('XXX',np.nan)
# Supression des valeurs non numériques de certaines colonnes et conversion de celles-ci au type float
off_df['Energie'] = off_df['Energie'].str.extract('(\d+)', expand=False).astype(float)
off_df['Sel'] = off_df['Sel'].str.extract('(\d+)', expand=False).astype(float)
off_df['Sucres'] = off_df['Sucres'].str.extract('(\d+)', expand=False).astype(float)
off_df['Acide_Gras'] = off_df['Acide_Gras'].str.extract('(\d+)', expand=False).astype(float)
off_df['Matiere_Grasse'] = off_df['Matiere_Grasse'].str.extract('(\d+)', expand=False).astype(float)

# %%
off_df
# Out:
#                                                     Nom     Code_Barre  \
# 0        Riz à la Méditerranéenne - Uncle Ben's - 250 g  3487400003805
# 1     Tartine bio craquant au sarrasin - Le pain des...        1153208
# 2                 Pur sirop d'érable - Maple joe - 250g  3088542500285
# 3             Quinoa poulet sesame - Jardin Bio - 250 g  3478820003193
# 4     Kinder schokobons bonbons de chocolat au lait ...  8000500242612
# ...                                                 ...            ...
# 1988                P'tit Nature Complet - Bjorg - 200g  3229820021027
# 1989  Tartines craquantes au sarrasin - Terres et cé...  3421557604089
# 1990    Céréales Corn Flakes Kellogg's Original - 500 g  3159470000120
# 1991  Country Crisp - Chocolat noir 70% cacao - Jord...  5010477348395
# 1992          Noir Prodigieux 90% cacao - Lindt - 100 g  3046920029759
#
#      Nutriscore                                          Novascore Ecoscore  \
# ...

# %%
off_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1993 entries, 0 to 1992
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Nom                  1993 non-null   object
#  1   Code_Barre           1984 non-null   object
#  2   Nutriscore           1886 non-null   object
#  3   Novascore            1913 non-null   object
#  4   Ecoscore             1674 non-null   object
#  5   Quantite             1960 non-null   object
#  6   Conditionnement      1919 non-null   object
#  7   Marques              1981 non-null   object
#  8   Categories           1984 non-null   object
#  9   Labels               1724 non-null   object
#  10  Origine_Ingredients  695 non-null    object
#  11  Pays_Transformation  1085 non-null   object
#  12  Code_tracage         547 non-null    object
#  13  URL                  672 non-null    object
#  14  Magasins             1689 non-null   object
# ...

# %% [markdown]
# ## Question 1 : Distribution du nombre de produits par catégorie

# %%
print('Voici la distribution du nombre de produits pour chaque catégories de Nutriscore, Novascore et Ecoscore')
print(off_df.groupby(['Nutriscore','Novascore','Ecoscore']).size())
# Out:
# Voici la distribution du nombre de produits pour chaque catégories de Nutriscore, Novascore et Ecoscore
# Nutriscore  Novascore                                                 Ecoscore
# A           1 - Aliments non transformés ou transformés minimalement  A            16
#                                                                       B            38
#                                                                       C            10
#                                                                       D             2
#                                                                       E             3
#             3 - Aliments transformés                                  A            34
#                                                                       B            56
#                                                                       C             8
#                                                                       D             3
# ...

# %% [markdown]
# ## Question 2 : Produits ayant "gluten free" optimaux (Nutri score A, Nova 1 et Ecoscore A)

# %%
print('Voici la liste des "meilleurs" produits gluten free')
off_df.loc[(off_df['Nutriscore'] == 'A') & (off_df['Novascore'].str.contains('1')) & (off_df['Ecoscore'] == 'A')]
# Out:
# Voici la liste des "meilleurs" produits gluten free
#                                                     Nom     Code_Barre  \
# 403   Léa Nature - Pomme Vanille bourbon - Jardin Bi...  3307131305170
# 646                      Tomaten gehakt - Nostia - 400g            NaN
# 743               Compote Pomme Nature - Andros - 730 g  3608580789758
# 970    Lentilles vertes cello - Vivien Paille - 500 g ℮  3039824100358
# 1148                   Panzani tomacouli nature - 200 g  3038352875066
# 1156    Boisson végétale soja sans sucres - Bjorg - 1 L  3229820019604
# 1182  Tartines craquantes bio au sarrasin sans glute...  3380380046940
# 1333  pomme morceaux sans sucre ajoute - Andros - 695 g  3045320517071
# 1391            Farine de blé suprême - Francine - 1 kg  3068110703232
# 1487  Boisson de soja nature sans sucre - Sojasun - 1 L  3273220080108
# 1662       Boisson au soja nature - Carrefour BIO - 1 l  3270190128717
# ...

# %% [markdown]
# ## Question 3 : Nombre de produit dont le ratio sucre/produit est supérieur à 0.6

# %%
result = off_df.loc[(off_df['Sucres'] / 100) > 0.6 ].shape[0]
print('Nous pouvons trouver dans le dataframe {} produits contenant un minimum de 60% de sucre'.format(result))
# Out:
# Nous pouvons trouver dans le dataframe 47 produits contenant un minimum de 60% de sucre

# %% [markdown]
# ## Question 4 : Liste des produits dont le nombre de calories est supérieur à 500

# %%
print('Voici la liste des produits dont le nombre de calories est supérieur à 500')
off_df.loc[(off_df['Energie'] >= 500)]
# Out:
# Voici la liste des produits dont le nombre de calories est supérieur à 500
#                                                     Nom     Code_Barre  \
# 4     Kinder schokobons bonbons de chocolat au lait ...  8000500242612
# 7          Mignonnette noir de noir - Côte d'or - 240 g  7622200002290
# 8     Excellence - Chocolat Caramel à la pointe de s...  3046920022507
# 14    Chips saveur Chèvre piment d^Espelette - Bret'...  3497917000518
# 30    Pâte à tartiner aux noisettes - Alter Eco - 270 g  3700214618240
# ...                                                 ...            ...
# 1963              Nocciolata - Rigoni di Asiago - 700 g  8001505005707
# 1967  Excellence - 100% cacao noir infini - Lindt - ...  3046920016377
# 1975  Le Beurre Tendre barquette doux - Elle & Vire ...  3451790988677
# 1979                  Granola - L'original - LU - 200 g  7622210601988
# 1992          Noir Prodigieux 90% cacao - Lindt - 100 g  3046920029759
#
# ...

# %% [markdown]
# ## Question 5 : Liste des produits contenant de l'huile de palme vendu en France et en Belgique

# %%
print('Voici la liste des produits vendu en France et Belgique contenant de l\'huile de palme')
off_df.loc[(off_df['Huile_Palme'].notnull()) & (off_df['Pays_Vente'].str.contains('Belgique|France'))]
# Out:
# Voici la liste des produits vendu en France et Belgique contenant de l'huile de palme
#                                                     Nom     Code_Barre  \
# 4     Kinder schokobons bonbons de chocolat au lait ...  8000500242612
# 12                      Pâte feuilletée - Herta - 230 g  7613038552927
# 13                  Prince goût tout choco - Lu - 300 g  7622210450098
# 26    Pain grillé de campagne Blé complet - Pelletie...  3017760542890
# 35                   Sablés Anglais - MCVITIE'S - 400 g  5000168198491
# ...                                                 ...            ...
# 1924       Primevère Bio doux Tartine & Cuisson - 250 g  3155250358788
# 1959                   Prince Goût Vanille - Lu - 300 g  7622210449979
# 1960                          Nutella - Ferrero - 750 g  3017620421006
# 1962        Granola Cookies Chocolat & Daim - Lu - 184g  7622300782443
# 1976  Bio muesli croustillant fruits rouges - Crownf...       20708399
#
# ...

# %% [markdown]
# ## Question 6 : Distribution des pays par nombre de pays de vente

# %%
# Je n'ai pas su répondre à cause du format liste de la colonne

# %% [markdown]
# ## Analyses supplémentaires

# %%
print('Voici la liste des produits contenant des additifs pouvant être dangereux pour la santé à force d\'exposition')
off_df[off_df['Additifs'].str.contains('Risque') == True]
# Out:
# Voici la liste des produits contenant des additifs pouvant être dangereux pour la santé à force d'exposition
#                                                     Nom     Code_Barre  \
# 29                                 Arome MAGGI - 200 ml  3033710084913
# 32                     Tuiles Pringles Barbecue - 175 g  5053990119189
# 43                                    Coca cola - 150ml       54491014
# 45                   Amora Moutarde Douce Bocal - 435 g  8722700139201
# 49                       Ice Tea pêche - Lipton - 33 cl  3168930159896
# ...                                                 ...            ...
# 1942  LE BROWNIE POCKET CHOCO PEPITES - Brossard - 2...  3498425591253
# 1943                   Zero Agrumes - Schweppes - 1,5 L  3124480002686
# 1951  Amora Moutarde de Dijon Fine et Forte Verre Tv...  3250547014115
# 1980  Flageolets cuisinés - sélection extra-fondants...  3083680085335
# 1983  Belvita Petit Déjeuner Original Chocolat - LU ...  7622210713780
#
# ...
